# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import M

# %%
rate=[7.1, 7.5, 8.2 ,8.6 , 8.9, 9.0, 9.3, 9.5 ]

revnue=[300000,4000000,5000000,1100000,12344321,43211234,12010202,7012660]
cols=[ rate,revnue]
scaler=MinMaxScaler()


df=pd.DataFrame({"Ratings":rate,"Revenue":revnue})

df[["Ratings","Revenue"]]=scaler.fit_transform(df[["Ratings","Revenue"]])
print(df)


plt.Figure(figsize=(4,3))
plt.plot(df["Ratings"])
plt.plot(df["Revenue"])
plt.legend()
plt.show()
# Out:
#     Ratings   Revenue
# 0  0.000000  0.000000
# 1  0.166667  0.086225
# 2  0.458333  0.109528
# 3  0.625000  0.018643
# 4  0.750000  0.280680
# 5  0.791667  1.000000
# 6  0.916667  0.272894
# 7  1.000000  0.156431
# C:\Users\WB\AppData\Local\Temp\ipykernel_24268\4069767233.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
