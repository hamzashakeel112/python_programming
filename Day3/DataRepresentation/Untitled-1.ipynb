# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
import matplotlib.pyplot as ptl
data=pd.read_csv("na-isal-year-ended-march-2025-sector-accounts.csv")
# dupdata=data.drop_duplicates()
# dupdata=data.dropna()

data.plot()
ptl.show()

# %%
import pandas as pd
import matplotlib.pyplot as ptl
data=pd.read_csv("na-isal-year-ended-march-2025-sector-accounts.csv")
dupdata=data.drop_duplicates()
dupdata=data.dropna()



dupdata.plot()
# print(data.info())
ptl.show()

# %%
import pandas as np
import matplotlib.pyplot as ptl
data=pd.read_csv("na-isal-year-ended-march-2025-sector-accounts.csv")
household_values = data[data["Series_title_4"] == "Households"]
household_values.drop_duplicates().dropna()
# Display the filtered single column
# print(household_values)
household_values.plot()
ptl.show()

# %%
import pandas as pd
import matplotlib.pyplot as ptl
data=pd.read_csv("na-isal-year-ended-march-2025-sector-accounts.csv")
market=data[data["Series_title_3"]=="Market"]
market.dropna()
market.plot()
ptl.show()

# %%
import pandas as pd
import matplotlib.pyplot as ptl
data=pd.read_csv("na-isal-year-ended-march-2025-sector-accounts.csv")

# unit=data["Units"]=="Dollars"
# 1. Filter the dataset to keep only rows where Units is "Dollars"
dollars_data = data[data["Units"] == "Dollars"]
dollars_data.plot(
    kind="line", title="Sector Account Values (Dollars)"
)
ptl.show()

# %%
import pandas as np
import matplotlib.pyplot as ptl
import seaborn as sns

data={
    "Math":[0.102,1.23,0.38],
    "Physic":[0.34,0.89,0.21],
    "Chemistry":[0.20,0.87,1.23]
}
df=pd.DataFrame(data)
matrix=df.corr(method="pearson")

sns.heatmap(matrix,annot=True, cmap="rocket")
ptl.show()
